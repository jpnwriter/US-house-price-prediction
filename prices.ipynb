# %% [markdown]
# Files downloaded on 20 Feb 2024:
#
# - 'CPIAUCSL.csv' - US CPI (inflation measure), monthly
# - 'RRVRUSQ156N.csv' - rental vacancy rate, quarterly
# - 'MORTGAGE30US.csv' - mortgage interest rates, weekly
# - 'Metro_mlp_uc_sfrcondo_week.csv' - median sale price for US houses
# - 'Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv' - Zillow home value index

# %%
import pandas as pd

fed_files = ["MORTGAGE30US.csv", "RRVRUSQ156N.csv", "CPIAUCSL.csv"]

dfs = [pd.read_csv(f, parse_dates=True, index_col=0) for f in fed_files]

# %%
dfs[0]
# Out:
#             MORTGAGE30US
# DATE
# 1971-04-02          7.33
# 1971-04-09          7.31
# 1971-04-16          7.31
# 1971-04-23          7.31
# 1971-04-30          7.29
# ...                  ...
# 2024-01-18          6.60
# 2024-01-25          6.69
# 2024-02-01          6.63
# 2024-02-08          6.64
# 2024-02-15          6.77
#
# [2760 rows x 1 columns]

# %%
dfs[1]
# Out:
#             RRVRUSQ156N
# DATE
# 1956-01-01          6.2
# 1956-04-01          5.9
# 1956-07-01          6.3
# 1956-10-01          5.8
# 1957-01-01          5.3
# ...                 ...
# 2022-10-01          5.8
# 2023-01-01          6.4
# 2023-04-01          6.3
# 2023-07-01          6.6
# 2023-10-01          6.6
#
# [272 rows x 1 columns]

# %%
dfs[2]
# Out:
#             CPIAUCSL
# DATE
# 1947-01-01    21.480
# 1947-02-01    21.620
# 1947-03-01    22.000
# 1947-04-01    22.000
# 1947-05-01    21.950
# ...              ...
# 2023-09-01   307.288
# 2023-10-01   307.531
# 2023-11-01   308.024
# 2023-12-01   308.742
# 2024-01-01   309.685
#
# [925 rows x 1 columns]

# %%
fed_data = pd.concat(dfs, axis=1)

# %%
fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1971-04-02          7.33          NaN       NaN
# 1971-04-09          7.31          NaN       NaN
# 1971-04-16          7.31          NaN       NaN
# 1971-04-23          7.31          NaN       NaN
# 1971-04-30          7.29          NaN       NaN
# ...                  ...          ...       ...
# 2023-08-01           NaN          NaN   306.187
# 2023-09-01           NaN          NaN   307.288
# 2023-11-01           NaN          NaN   308.024
# 2023-12-01           NaN          NaN   308.742
# 2024-01-01           NaN          NaN   309.685
#
# [3601 rows x 3 columns]

# %%
fed_data.tail(50)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2016-11-01           NaN          NaN   242.026
# 2017-02-01           NaN          NaN   244.006
# 2017-03-01           NaN          NaN   243.892
# 2017-05-01           NaN          NaN   244.004
# 2017-08-01           NaN          NaN   245.183
# 2017-09-01           NaN          NaN   246.435
# 2017-11-01           NaN          NaN   247.284
# 2017-12-01           NaN          NaN   247.805
# 2018-05-01           NaN          NaN   250.792
# 2018-06-01           NaN          NaN   251.018
# 2018-08-01           NaN          NaN   251.663
# 2018-09-01           NaN          NaN   252.182
# 2018-12-01           NaN          NaN   252.767
# 2019-02-01           NaN          NaN   253.319
# 2019-03-01           NaN          NaN   254.277
# 2019-05-01           NaN          NaN   255.296
# 2019-06-01           NaN          NaN   255.213
# 2019-09-01           NaN          NaN   256.430
# 2019-11-01           NaN          NaN   257.879
# 2019-12-01           NaN          NaN   258.630
# 2020-02-01           NaN          NaN   259.246
# 2020-03-01           NaN          NaN   258.150
# 2020-05-01           NaN          NaN   255.848
# 2020-06-01           NaN          NaN   257.004
# 2020-08-01           NaN          NaN   259.366
# 2020-09-01           NaN          NaN   259.951
# 2020-11-01           NaN          NaN   260.895
# 2020-12-01           NaN          NaN   262.005
# 2021-02-01           NaN          NaN   263.583
# 2021-03-01           NaN          NaN   264.910
# 2021-05-01           NaN          NaN   268.452
# 2021-06-01           NaN          NaN   270.664
# 2021-08-01           NaN          NaN   272.789
# 2021-09-01           NaN          NaN   273.887
# 2021-11-01           NaN          NaN   278.799
# 2021-12-01           NaN          NaN   280.808
# 2022-02-01           NaN          NaN   284.535
# 2022-03-01           NaN          NaN   287.553
# 2022-05-01           NaN          NaN   291.359
# 2022-06-01           NaN          NaN   294.996
# 2022-08-01           NaN          NaN   295.209
# 2022-11-01           NaN          NaN   298.648
# 2023-02-01           NaN          NaN   301.509
# 2023-03-01           NaN          NaN   301.744
# 2023-05-01           NaN          NaN   303.365
# 2023-08-01           NaN          NaN   306.187
# 2023-09-01           NaN          NaN   307.288
# 2023-11-01           NaN          NaN   308.024
# 2023-12-01           NaN          NaN   308.742
# 2024-01-01           NaN          NaN   309.685

# %%
fed_data = fed_data.ffill()

# %%
fed_data.tail()
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2023-08-01          6.77          6.6   306.187
# 2023-09-01          6.77          6.6   307.288
# 2023-11-01          6.77          6.6   308.024
# 2023-12-01          6.77          6.6   308.742
# 2024-01-01          6.77          6.6   309.685

# %%
zillow_files = ["Metro_mlp_uc_sfrcondo_week.csv", "Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv"]

dfs = [pd.read_csv(f) for f in zillow_files]

# %%
dfs[0]
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-01-13  \
# 0      102001         0    United States    country       NaN    259900.0
# 1      394913         1     New York, NY        msa        NY    499000.0
# 2      753899         2  Los Angeles, CA        msa        CA    750000.0
# 3      394463         3      Chicago, IL        msa        IL    279500.0
# 4      394514         4       Dallas, TX        msa        TX    331300.0
# ..        ...       ...              ...        ...       ...         ...
# 920    753929       935       Zapata, TX        msa        TX         NaN
# 921    394743       936    Ketchikan, AK        msa        AK    283500.0
# 922    753874       937        Craig, CO        msa        CO    190500.0
# 923    395188       938       Vernon, TX        msa        TX         NaN
# 924    394767       939       Lamesa, TX        msa        TX         NaN
#
#      2018-01-20  2018-01-27  2018-02-03  2018-02-10  ...  2023-12-02  \
# 0      259900.0    260000.0    264000.0    265000.0  ...    390000.0
# 1      499000.0    499000.0    499999.0    525000.0  ...    699000.0
# 2      758000.0    757500.0    750000.0    755000.0  ...   1050000.0
# 3      279900.0    284900.0    285000.0    292900.0  ...    334975.0
# 4      331590.0    335000.0    337800.0    339900.0  ...    429900.0
# ..          ...         ...         ...         ...  ...         ...
# 920         NaN         NaN         NaN         NaN  ...    153000.0
# 921    289000.0    299900.0    289500.0    284000.0  ...    454000.0
# 922    191000.0    195000.0    192000.0    189000.0  ...    299450.0
# 923         NaN         NaN         NaN         NaN  ...    135000.0
# 924         NaN         NaN         NaN         NaN  ...    186500.0
#
#      2023-12-09  2023-12-16  2023-12-23  2023-12-30  2024-01-06  2024-01-13  \
# 0      389900.0    389000.0    385000.0    385000.0    385000.0    385000.0
# 1      699806.0    699900.0    699000.0    699900.0    699000.0    699000.0
# 2     1032900.0   1025000.0   1002500.0         NaN   1049000.0         NaN
# 3      330000.0    329900.0    325000.0    325000.0    325000.0    329000.0
# 4      429000.0    425000.0    424900.0    424936.0    420000.0    420000.0
# ..          ...         ...         ...         ...         ...         ...
# 920    146500.0    155500.0    158000.0    158000.0    158000.0    161500.0
# 921    454000.0    449000.0    429000.0    414500.0    429000.0    429000.0
# 922    317231.0    322276.0    314900.0    318500.0    307450.0    299450.0
# 923    135000.0    132500.0    130000.0    130000.0    130000.0    129500.0
# 924    192500.0    205000.0    199995.0    195000.0    190000.0    189000.0
#
#      2024-01-20  2024-01-27  2024-02-03
# 0      387000.0    388000.0    389000.0
# 1      699000.0    699000.0    699998.0
# 2      999999.0   1020000.0   1050000.0
# 3      329900.0    329000.0    329900.0
# 4      420000.0    420000.0    420000.0
# ..          ...         ...         ...
# 920    161500.0    159900.0    158950.0
# 921    429000.0    424000.0    424000.0
# 922    299900.0    285000.0    299000.0
# 923    129750.0    118000.0    120000.0
# 924    187000.0    187500.0    187000.0
#
# [925 rows x 322 columns]

# %%
dfs = [pd.DataFrame(df.iloc[0,5:]) for df in dfs]

# %%
dfs[0]
# Out:
#                    0
# 2018-01-13  259900.0
# 2018-01-20  259900.0
# 2018-01-27  260000.0
# 2018-02-03  264000.0
# 2018-02-10  265000.0
# ...              ...
# 2024-01-06  385000.0
# 2024-01-13  385000.0
# 2024-01-20  387000.0
# 2024-01-27  388000.0
# 2024-02-03  389000.0
#
# [317 rows x 1 columns]

# %%
dfs[1]
# Out:
#                         0
# 2000-01-31  118650.519637
# 2000-02-29  118859.263937
# 2000-03-31  119118.137606
# 2000-04-30   119673.37081
# 2000-05-31  120312.377661
# ...                   ...
# 2023-09-30  340565.687554
# 2023-10-31  341463.377812
# 2023-11-30  342099.321005
# 2023-12-31  342521.353044
# 2024-01-31   342941.32932
#
# [289 rows x 1 columns]

# %%
for df in dfs:
    df.index = pd.to_datetime(df.index)
    df["month"] = df.index.to_period("M")

# %%
dfs[0]
# Out:
#                    0    month
# 2018-01-13  259900.0  2018-01
# 2018-01-20  259900.0  2018-01
# 2018-01-27  260000.0  2018-01
# 2018-02-03  264000.0  2018-02
# 2018-02-10  265000.0  2018-02
# ...              ...      ...
# 2024-01-06  385000.0  2024-01
# 2024-01-13  385000.0  2024-01
# 2024-01-20  387000.0  2024-01
# 2024-01-27  388000.0  2024-01
# 2024-02-03  389000.0  2024-02
#
# [317 rows x 2 columns]

# %%
dfs[1]
# Out:
#                         0    month
# 2000-01-31  118650.519637  2000-01
# 2000-02-29  118859.263937  2000-02
# 2000-03-31  119118.137606  2000-03
# 2000-04-30   119673.37081  2000-04
# 2000-05-31  120312.377661  2000-05
# ...                   ...      ...
# 2023-09-30  340565.687554  2023-09
# 2023-10-31  341463.377812  2023-10
# 2023-11-30  342099.321005  2023-11
# 2023-12-31  342521.353044  2023-12
# 2024-01-31   342941.32932  2024-01
#
# [289 rows x 2 columns]

# %%
price_data = dfs[0].merge(dfs[1], on="month")

# %%
price_data
# Out:
#           0_x    month            0_y
# 0    259900.0  2018-01  216884.583462
# 1    259900.0  2018-01  216884.583462
# 2    260000.0  2018-01  216884.583462
# 3    264000.0  2018-02  218061.199245
# 4    265000.0  2018-02  218061.199245
# ..        ...      ...            ...
# 311  385000.0  2023-12  342521.353044
# 312  385000.0  2024-01   342941.32932
# 313  385000.0  2024-01   342941.32932
# 314  387000.0  2024-01   342941.32932
# 315  388000.0  2024-01   342941.32932
#
# [316 rows x 3 columns]

# %%
len(price_data)
# Out:
# 316

# %%
len(dfs[0])
# Out:
# 317

# %%
dfs[0] = dfs[0].drop(dfs[0].index[-1])

# %%
len(dfs[0])
# Out:
# 316

# %%
price_data.index = dfs[0].index

# %%
price_data
# Out:
#                  0_x    month            0_y
# 2018-01-13  259900.0  2018-01  216884.583462
# 2018-01-20  259900.0  2018-01  216884.583462
# 2018-01-27  260000.0  2018-01  216884.583462
# 2018-02-03  264000.0  2018-02  218061.199245
# 2018-02-10  265000.0  2018-02  218061.199245
# ...              ...      ...            ...
# 2023-12-30  385000.0  2023-12  342521.353044
# 2024-01-06  385000.0  2024-01   342941.32932
# 2024-01-13  385000.0  2024-01   342941.32932
# 2024-01-20  387000.0  2024-01   342941.32932
# 2024-01-27  388000.0  2024-01   342941.32932
#
# [316 rows x 3 columns]

# %%
del price_data["month"]
price_data.columns = ["price", "value"]

# %%
price_data
# Out:
#                price          value
# 2018-01-13  259900.0  216884.583462
# 2018-01-20  259900.0  216884.583462
# 2018-01-27  260000.0  216884.583462
# 2018-02-03  264000.0  218061.199245
# 2018-02-10  265000.0  218061.199245
# ...              ...            ...
# 2023-12-30  385000.0  342521.353044
# 2024-01-06  385000.0   342941.32932
# 2024-01-13  385000.0   342941.32932
# 2024-01-20  387000.0   342941.32932
# 2024-01-27  388000.0   342941.32932
#
# [316 rows x 2 columns]

# %%
fed_data = fed_data.dropna()

# %%
fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1971-10-01          7.67          5.6    40.900
# 1971-10-08          7.63          5.6    40.900
# 1971-10-15          7.63          5.6    40.900
# 1971-10-22          7.58          5.6    40.900
# 1971-10-29          7.63          5.6    40.900
# ...                  ...          ...       ...
# 2023-08-01          6.77          6.6   306.187
# 2023-09-01          6.77          6.6   307.288
# 2023-11-01          6.77          6.6   308.024
# 2023-12-01          6.77          6.6   308.742
# 2024-01-01          6.77          6.6   309.685
#
# [3575 rows x 3 columns]

# %%
from datetime import timedelta

fed_data.index = fed_data.index + timedelta(days=2)

# %%
fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1971-10-03          7.67          5.6    40.900
# 1971-10-10          7.63          5.6    40.900
# 1971-10-17          7.63          5.6    40.900
# 1971-10-24          7.58          5.6    40.900
# 1971-10-31          7.63          5.6    40.900
# ...                  ...          ...       ...
# 2023-08-03          6.77          6.6   306.187
# 2023-09-03          6.77          6.6   307.288
# 2023-11-03          6.77          6.6   308.024
# 2023-12-03          6.77          6.6   308.742
# 2024-01-03          6.77          6.6   309.685
#
# [3575 rows x 3 columns]

# %%
price_data = fed_data.merge(price_data, left_index=True, right_index=True)

# %%
price_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL     price          value
# 2018-01-13          3.99          7.0   244.163  259900.0  216884.583462
# 2018-01-20          4.04          7.0   244.163  259900.0  216884.583462
# 2018-01-27          4.15          7.0   244.163  260000.0  216884.583462
# 2018-02-03          4.22          7.0   249.529  264000.0  218061.199245
# 2018-02-10          4.32          7.0   249.529  265000.0  218061.199245
# ...                  ...          ...       ...       ...            ...
# 2023-12-30          6.61          5.8   304.003  385000.0  342521.353044
# 2024-01-06          6.62          5.8   304.003  385000.0   342941.32932
# 2024-01-13          6.66          5.8   304.003  385000.0   342941.32932
# 2024-01-20          6.60          5.8   304.003  387000.0   342941.32932
# 2024-01-27          6.69          5.8   304.003  388000.0   342941.32932
#
# [308 rows x 5 columns]

# %%
price_data.columns = ["interest", "vacancy", "cpi", "price", "value"]

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value
# 2018-01-13      3.99      7.0  244.163  259900.0  216884.583462
# 2018-01-20      4.04      7.0  244.163  259900.0  216884.583462
# 2018-01-27      4.15      7.0  244.163  260000.0  216884.583462
# 2018-02-03      4.22      7.0  249.529  264000.0  218061.199245
# 2018-02-10      4.32      7.0  249.529  265000.0  218061.199245
# ...              ...      ...      ...       ...            ...
# 2023-12-30      6.61      5.8  304.003  385000.0  342521.353044
# 2024-01-06      6.62      5.8  304.003  385000.0   342941.32932
# 2024-01-13      6.66      5.8  304.003  385000.0   342941.32932
# 2024-01-20      6.60      5.8  304.003  387000.0   342941.32932
# 2024-01-27      6.69      5.8  304.003  388000.0   342941.32932
#
# [308 rows x 5 columns]

# %%
price_data.plot.line(y="price", use_index=True)
# Out:
# <Axes: >

# %%
price_data["adj_price"] = price_data["price"] / price_data["cpi"] * 100

# %%
price_data.plot.line(y="adj_price", use_index=True)
# Out:
# <Axes: >

# %%
price_data["adj_value"] = price_data["value"] / price_data["cpi"] * 100

# %%
price_data.plot.line(y="adj_value", use_index=True)
# Out:
# <Axes: >

# %%
price_data["next_quarter"] = price_data["adj_price"].shift(-13)

# %%
price_data.tail(20)
# Out:
#             interest  vacancy      cpi     price          value  \
# 2023-09-09      7.12      5.8  304.003  400000.0  340565.687554
# 2023-09-16      7.18      5.8  304.003  400000.0  340565.687554
# 2023-09-23      7.19      5.8  304.003  399999.0  340565.687554
# 2023-09-30      7.31      5.8  304.003  399943.0  340565.687554
# 2023-10-07      7.49      5.8  304.003  399900.0  341463.377812
# 2023-10-14      7.57      5.8  304.003  399900.0  341463.377812
# 2023-10-21      7.63      5.8  304.003  399900.0  341463.377812
# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# %%
start = 104
step = 52

def predict(train, test, predictors, target):
    rf = RandomForestClassifier(min_samples_split=10, random_state=1)
    rf.fit(train[predictors], train[target])
    preds = rf.predict(test[predictors])
    return preds

def backtest(data, predictors, target):
    all_preds = []
    for i in range(start, data.shape[0], step):
        train = price_data.iloc[:i]
        test = price_data.iloc[i:(i+step)]
        all_preds.append(predict(train, test, predictors, target))

    preds = np.concatenate(all_preds)
    return preds, accuracy_score(data.iloc[start:][target], preds)

# %%
preds, accuracy = backtest(price_data, predictors, target)

# %%
accuracy
# Out:
# 0.6190476190476191

# %%
yearly = price_data.rolling(52, min_periods=1).mean()

# %%
yearly
# Out:
#             interest  vacancy         cpi          price          value  \
# 2018-01-13  3.990000      7.0  244.163000  259900.000000  216884.583462
# 2018-01-20  4.015000      7.0  244.163000  259900.000000  216884.583462
# 2018-01-27  4.060000      7.0  244.163000  259933.333333  216884.583462
# 2018-02-03  4.100000      7.0  245.504500  260950.000000  217178.737407
# 2018-02-10  4.144000      7.0  246.309400  261760.000000  217355.229775
# ...              ...      ...         ...            ...            ...
# 2023-09-23  6.629615      5.8  300.081385  398686.480769  335057.688085
# 2023-09-30  6.649231      5.8  300.228731  398687.307692  335130.627295
# 2023-10-07  6.664423      5.8  300.376077  398687.307692  335243.763335
# 2023-10-14  6.681923      5.8  300.523423  398704.615385  335356.899375
# 2023-10-21  6.695577      5.8  300.670769  398721.923077  335470.035416
#
#                 adj_price      adj_value   next_quarter    change
# 2018-01-13  106445.284503   88827.784497  114153.147125  1.000000
# 2018-01-20  106445.284503   88827.784497  114173.181022  1.000000
# 2018-01-27  106458.936585   88827.784497  114580.536935  1.000000
# 2018-02-03  106294.033921   88468.118573  114934.469122  1.000000
# 2018-02-10  106275.243327   88252.319019  115178.882669  1.000000
# ...                   ...            ...            ...       ...
# 2023-09-23  132848.648312  111659.708393  132311.888271  0.423077
# 2023-09-30  132783.513871  111628.619753  132302.401579  0.423077
# 2023-10-07  132718.107418  111610.948674  132298.707055  0.423077
# 2023-10-14  132658.541430  111593.277594  132307.664228  0.423077
# 2023-10-21  132598.975442  111575.606515  132317.155082  0.423077
#
# [293 rows x 9 columns]

# %%
yearly_ratios = [p + "_year" for p in predictors]
price_data[yearly_ratios] = price_data[predictors] / yearly[predictors]

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2018-01-13      3.99      7.0  244.163  259900.0  216884.583462
# 2018-01-20      4.04      7.0  244.163  259900.0  216884.583462
# 2018-01-27      4.15      7.0  244.163  260000.0  216884.583462
# 2018-02-03      4.22      7.0  249.529  264000.0  218061.199245
# 2018-02-10      4.32      7.0  249.529  265000.0  218061.199245
# ...              ...      ...      ...       ...            ...
# 2023-09-23      7.19      5.8  304.003  399999.0  340565.687554
# 2023-09-30      7.31      5.8  304.003  399943.0  340565.687554
# 2023-10-07      7.49      5.8  304.003  399900.0  341463.377812
# 2023-10-14      7.57      5.8  304.003  399900.0  341463.377812
# 2023-10-21      7.63      5.8  304.003  399900.0  341463.377812
#
#                 adj_price      adj_value   next_quarter  change  \
# 2018-01-13  106445.284503   88827.784497  114153.147125       1
# 2018-01-20  106445.284503   88827.784497  114193.214920       1
# 2018-01-27  106486.240749   88827.784497  115395.248761       1
# 2018-02-03  105799.325930   87389.120801  115996.265682       1
# 2018-02-10  106200.080953   87389.120801  116156.536860       1
# ...                   ...            ...            ...     ...
# 2023-09-23  131577.319961  112027.081165  126643.487071       0
# 2023-09-30  131558.899090  112027.081165  126643.487071       0
# 2023-10-07  131544.754493  112322.371099  126643.487071       0
# 2023-10-14  131544.754493  112322.371099  127301.375315       0
# 2023-10-21  131544.754493  112322.371099  127630.319438       0
#
#             interest_year  vacancy_year  adj_price_year  adj_value_year
# 2018-01-13       1.000000           1.0        1.000000        1.000000
# 2018-01-20       1.006227           1.0        1.000000        1.000000
# 2018-01-27       1.022167           1.0        1.000256        1.000000
# 2018-02-03       1.029268           1.0        0.995346        0.987804
# 2018-02-10       1.042471           1.0        0.999293        0.990219
# ...                   ...           ...             ...             ...
# 2023-09-23       1.084527           1.0        0.990430        1.003290
# 2023-09-30       1.099375           1.0        0.990777        1.003570
# 2023-10-07       1.123878           1.0        0.991159        1.006374
# 2023-10-14       1.132907           1.0        0.991604        1.006533
# 2023-10-21       1.139558           1.0        0.992050        1.006693
#
# [293 rows x 13 columns]

# %%
preds, accuracy = backtest(price_data, predictors + yearly_ratios, target)

# %%
accuracy
# Out:
# 0.5661375661375662

# %%
pred_match = (preds == price_data[target].iloc[start:])

# %%
pred_match[pred_match == True] = "green"
pred_match[pred_match == False] = "red"
# Out:
# /var/folders/mx/p_dw3l351sb1h38x8l37yfdw0000gn/T/ipykernel_1347/1532675083.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'green' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   pred_match[pred_match == True] = "green"

# %%
import matplotlib.pyplot as plt

plot_data = price_data.iloc[start:].copy()

plot_data.reset_index().plot.scatter(x="index", y="adj_price", color=pred_match)
# Out:
# <Axes: xlabel='index', ylabel='adj_price'>

# %%
from sklearn.inspection import permutation_importance

rf = RandomForestClassifier(min_samples_split=10, random_state=1)
rf.fit(price_data[predictors], price_data[target])

results = permutation_importance(rf, price_data[predictors], price_data[target], n_repeats=10, random_state=1)

# %%
results["importances_mean"]
# Out:
# array([0.24948805, 0.00068259, 0.30682594, 0.20750853])

# %%
predictors
# Out:
# ['interest', 'vacancy', 'adj_price', 'adj_value']

# %% [markdown]
# Next steps

# %%
#the plots are showing an issue with the dataframe and will need to be reviewed to show more accuracy
#after review, tune the rf 
#get more economic indicators - stock market indicators, alt. commodities (gold, alt. assets)
#get sentiment from news articles, media
#get info on where are new houses are being built, or external events such as natural disasters
#personalise the model for your area (will require another folder with AU and JP records)
#use another ML algorithm
